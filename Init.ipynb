# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting nixtla (from -r ./requirements.txt (line 2))
#   Downloading nixtla-0.7.1-py3-none-any.whl.metadata (14 kB)
# Collecting StatsForecast==2.0.3 (from -r ./requirements.txt (line 4))
#   Downloading statsforecast-2.0.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.11/site-packages (from StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2.2.1)
# Collecting coreforecast>=0.0.12 (from StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading coreforecast-0.0.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Collecting numba>=0.55.0 (from StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading numba-0.62.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.21.6 in /root/venv/lib/python3.11/site-packages (from StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: pandas>=1.3.5 in /root/venv/lib/python3.11/site-packages (from StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2.1.4)
# Requirement already satisfied: scipy<1.16.0,>=1.7.3 in /root/venv/lib/python3.11/site-packages (from StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (1.11.4)
# Collecting statsmodels>=0.13.2 (from StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading statsmodels-0.14.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: tqdm in /root/venv/lib/python3.11/site-packages (from StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (4.67.1)
# Collecting fugue>=0.8.1 (from StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading fugue-0.9.3-py3-none-any.whl.metadata (18 kB)
# Collecting utilsforecast>=0.1.4 (from StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading utilsforecast-0.2.15-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=3 in /root/venv/lib/python3.11/site-packages (from StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: annotated-types in /root/venv/lib/python3.11/site-packages (from nixtla->-r ./requirements.txt (line 2)) (0.7.0)
# Collecting httpx[zstd] (from nixtla->-r ./requirements.txt (line 2))
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson (from nixtla->-r ./requirements.txt (line 2))
#   Downloading orjson-3.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.10 in /root/venv/lib/python3.11/site-packages (from nixtla->-r ./requirements.txt (line 2)) (2.11.10)
# Requirement already satisfied: tenacity in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from nixtla->-r ./requirements.txt (line 2)) (9.0.0)
# Collecting triad>=1.0.0 (from fugue>=0.8.1->StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading triad-1.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting adagio>=0.2.6 (from fugue>=0.8.1->StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading adagio-0.2.6-py3-none-any.whl.metadata (1.8 kB)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.55.0->StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading llvmlite-0.45.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.11/site-packages (from pandas>=1.3.5->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas>=1.3.5->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas>=1.3.5->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: pydantic-core==2.33.2 in /root/venv/lib/python3.11/site-packages (from pydantic>=1.10->nixtla->-r ./requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /root/venv/lib/python3.11/site-packages (from pydantic>=1.10->nixtla->-r ./requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /root/venv/lib/python3.11/site-packages (from pydantic>=1.10->nixtla->-r ./requirements.txt (line 2)) (0.4.2)
# Collecting patsy>=0.5.6 (from statsmodels>=0.13.2->StatsForecast==2.0.3->-r ./requirements.txt (line 4))
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.11/site-packages (from statsmodels>=0.13.2->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (25.0)
# Requirement already satisfied: narwhals>=2.0 in /root/venv/lib/python3.11/site-packages (from utilsforecast>=0.1.4->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2.12.0)
# Collecting anyio (from httpx[zstd]->nixtla->-r ./requirements.txt (line 2))
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /root/venv/lib/python3.11/site-packages (from httpx[zstd]->nixtla->-r ./requirements.txt (line 2)) (2025.11.12)
# Collecting httpcore==1.* (from httpx[zstd]->nixtla->-r ./requirements.txt (line 2))
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /root/venv/lib/python3.11/site-packages (from httpx[zstd]->nixtla->-r ./requirements.txt (line 2)) (3.11)
# Collecting zstandard>=0.18.0 (from httpx[zstd]->nixtla->-r ./requirements.txt (line 2))
#   Downloading zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx[zstd]->nixtla->-r ./requirements.txt (line 2))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: pyarrow>=6.0.1 in /toolkit-cache/1.1.6/python3.11/kernel-libs/lib/python3.11/site-packages (from triad>=1.0.0->fugue>=0.8.1->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (17.0.0)
# Requirement already satisfied: fsspec>=2022.5.0 in /root/venv/lib/python3.11/site-packages (from triad>=1.0.0->fugue>=0.8.1->StatsForecast==2.0.3->-r ./requirements.txt (line 4)) (2025.10.0)
# Downloading statsforecast-2.0.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 350.0/350.0 kB 51.5 MB/s eta 0:00:00
# Downloading nixtla-0.7.1-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.6/127.6 kB 30.0 MB/s eta 0:00:00
# Downloading coreforecast-0.0.16-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 59.9 MB/s eta 0:00:00
# Downloading fugue-0.9.3-py3-none-any.whl (280 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.7/280.7 kB 59.8 MB/s eta 0:00:00
# Downloading numba-0.62.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 98.8 MB/s eta 0:00:00
# Downloading statsmodels-0.14.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 104.3 MB/s eta 0:00:00
# Downloading utilsforecast-0.2.15-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 7.9 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 16.4 MB/s eta 0:00:00
# Downloading orjson-3.11.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (136 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.2/136.2 kB 27.9 MB/s eta 0:00:00
# Downloading adagio-0.2.6-py3-none-any.whl (19 kB)
# Downloading llvmlite-0.45.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 52.1 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 20.8 MB/s eta 0:00:00
# Downloading triad-1.0.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 12.2 MB/s eta 0:00:00
# Downloading zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 76.4 MB/s eta 0:00:00
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 22.6 MB/s eta 0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 14.8 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: zstandard, patsy, orjson, llvmlite, h11, coreforecast, anyio, numba, httpcore, utilsforecast, triad, statsmodels, httpx, adagio, nixtla, fugue, StatsForecast
# Successfully installed StatsForecast-2.0.3 adagio-0.2.6 anyio-4.12.0 coreforecast-0.0.16 fugue-0.9.3 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 llvmlite-0.45.1 nixtla-0.7.1 numba-0.62.1 orjson-3.11.4 patsy-1.0.2 statsmodels-0.14.5 triad-1.0.0 utilsforecast-0.2.15 zstandard-0.25.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
